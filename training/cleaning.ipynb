# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"../data/Amravati_merged.csv")
df.shape
# Out:
# (2485, 23)

# %%
df.describe()
# Out:
#        PM2.5 (µg/m³)  PM10 (µg/m³)   NO (µg/m³)  NO2 (µg/m³)    NOx (ppb)  \
# count    2404.000000   2411.000000  2412.000000  2412.000000  2412.000000
# mean       31.226560     62.932981     2.975863    14.727165    10.200649
# std        24.775908     40.828206     2.880521    14.001893     9.038952
# min         1.101852      3.910000     0.250000     1.660000     0.880000
# 25%        12.172500     29.730000     1.790000     7.597500     5.690000
# 50%        23.290000     53.120000     2.139792    10.958819     7.730000
# 75%        42.958472     87.992778     2.918281    16.250000    10.980000
# max       141.960000    261.750000    43.760000   140.580000   105.120000
#
#        NH3 (µg/m³)  SO2 (µg/m³)   CO (mg/m³)  Ozone (µg/m³)  Benzene (µg/m³)  \
# count  2412.000000  2397.000000  2368.000000    2412.000000      2386.000000
# mean     12.817788    13.812268     0.626000      34.651880         0.516617
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2485 entries, 0 to 2484
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            2485 non-null   object
#  1   PM2.5 (µg/m³)        2404 non-null   float64
#  2   PM10 (µg/m³)         2411 non-null   float64
#  3   NO (µg/m³)           2412 non-null   float64
#  4   NO2 (µg/m³)          2412 non-null   float64
#  5   NOx (ppb)            2412 non-null   float64
#  6   NH3 (µg/m³)          2412 non-null   float64
#  7   SO2 (µg/m³)          2397 non-null   float64
#  8   CO (mg/m³)           2368 non-null   float64
#  9   Ozone (µg/m³)        2412 non-null   float64
#  10  Benzene (µg/m³)      2386 non-null   float64
#  11  Toluene (µg/m³)      2386 non-null   float64
#  12  Xylene (µg/m³)       1780 non-null   float64
#  13  O Xylene (µg/m³)     0 non-null      float64
#  14  Eth-Benzene (µg/m³)  0 non-null      float64
# ...

# %%
df.isna().sum()
# Out:
# Timestamp                 0
# PM2.5 (µg/m³)            81
# PM10 (µg/m³)             74
# NO (µg/m³)               73
# NO2 (µg/m³)              73
# NOx (ppb)                73
# NH3 (µg/m³)              73
# SO2 (µg/m³)              88
# CO (mg/m³)              117
# Ozone (µg/m³)            73
# Benzene (µg/m³)          99
# Toluene (µg/m³)          99
# Xylene (µg/m³)          705
# O Xylene (µg/m³)       2485
# Eth-Benzene (µg/m³)    2485
# MP-Xylene (µg/m³)        99
# AT (°C)                  77
# RH (%)                   83
# WS (m/s)                 75
# WD (deg)                 75
# RF (mm)                  73
# TOT-RF (mm)               0
# SR (W/mt2)               75
# BP (mmHg)                75
# VWS (m/s)                75
# dtype: int64

# %%
df.drop(columns= [ "SR (W/mt2)"], inplace=True)

# %%
df.isna().sum()
# Out:
# Timestamp                 0
# PM2.5 (µg/m³)            81
# PM10 (µg/m³)             74
# NO (µg/m³)               73
# NO2 (µg/m³)              73
# NOx (ppb)                73
# NH3 (µg/m³)              73
# SO2 (µg/m³)              88
# CO (mg/m³)              117
# Ozone (µg/m³)            73
# Benzene (µg/m³)          99
# Toluene (µg/m³)          99
# Xylene (µg/m³)          705
# O Xylene (µg/m³)       2485
# Eth-Benzene (µg/m³)    2485
# MP-Xylene (µg/m³)        99
# AT (°C)                  77
# RH (%)                   83
# WS (m/s)                 75
# WD (deg)                 75
# RF (mm)                  73
# TOT-RF (mm)               0
# BP (mmHg)                75
# dtype: int64

# %%
df.to_csv('../data/Amravati_merged.csv', index=False)

# %%
df.shape
# Out:
# (2485, 23)

# %%
df.shape
# Out:
# (2485, 23)
